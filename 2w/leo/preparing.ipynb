# %% [markdown]
# # 3w preparing
#
# ## 작업 순서
#
# ### 1. 정규화
#
# 1. 문장 부호 제거 : 단어 단위에서
# 2. 소문자/대문자 변환 : 전체에서
# 3. 불용어 처리 : 단어 단위에서
# 4. 약어 대체 : 전체에서
# 5. 반복되는 문자 처리 : 단어 단위에서
#
# ### 2. 토큰화
#
# 1. 텍스트 -> 문장
# 2. 문자 -> 단어

# %%
import pandas as pd
import numpy as np
import os, sys, warnings
from tqdm import tqdm_notebook as tqdm
import re, string
import nltk
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

warnings.filterwarnings('ignore')
sys.path.append(os.path.abspath(os.path.dirname('../../modules/')))
from replacers import RegexpReplacer, RepeatReplacer, WordReplacer

# %%
path_github = '../../dataset/github/'
os.listdir(path_github)
# Out:
# ['constants.py',
#  'CONTRIBUTING.md',
#  'gap-development.tsv',
#  'gap-test.tsv',
#  'gap-validation.tsv',
#  'gap_scorer.py',
#  'LICENSE',
#  'README.md']

# %%
test = pd.read_csv(path_github+'gap-test.tsv', sep='\t')
validation = pd.read_csv(path_github+'gap-validation.tsv', sep='\t')
train = pd.read_csv(path_github+'gap-development.tsv', sep='\t')

# %%
validation.head()
# Out:
#              ID                                               Text Pronoun  \
# 0  validation-1  He admitted making four trips to China and pla...     him
# 1  validation-2  Kathleen Nott was born in Camberwell, London. ...     She
# 2  validation-3  When she returns to her hotel room, a Liberian...     his
# 3  validation-4  On 19 March 2007, during a campaign appearance...      he
# 4  validation-5  By this time, Karen Blixen had separated from ...     she
#
#    Pronoun-offset                   A  A-offset  A-coref              B  \
# 0             256  Jose de Venecia Jr       208    False         Abalos
# 1             185               Ellen       110    False       Kathleen
# 2             435     Jason Scott Lee       383    False          Danny
# 3             333           Reucassel       300     True         Debnam
# 4             427        Finch Hatton       290    False  Beryl Markham
#
#    B-offset  B-coref                                                URL
# 0       241    False  http://en.wikipedia.org/wiki/Commission_on_Ele...
# 1       150     True         http://en.wikipedia.org/wiki/Kathleen_Nott
# 2       406     True  http://en.wikipedia.org/wiki/Hawaii_Five-0_(20...
# 3       325    False       http://en.wikipedia.org/wiki/Craig_Reucassel
# 4       328     True    http://en.wikipedia.org/wiki/Denys_Finch_Hatton

# %%
# 대/소문자
def lower_casing(x):
    return x.lower()

# 약어 대체
reg_exp_replacer = RegexpReplacer()

# 단어 토큰화
def word_tokenizing(doc): # doc 단위로
    return map(nltk.word_tokenize, doc) # sent 단위로

# 문장 부호 제거
punctuation_replacer = re.compile('[%s]'%re.escape(string.punctuation))
def punctuation_replacing(doc):
    ret = []
    for sent in doc:
        sent_ret = []
        for word in sent:
            temp = punctuation_replacer.sub(u'', word)
            if not temp == u'': 
                sent_ret.append(temp)
        ret.append(sent_ret)
    return ret
    
# 불용어 제거
stop_words = set(stopwords.words('english'))
def stop_words_replacing(doc):
    ret = []
    for sent in doc:
        ret.append([word for word in sent if word not in stop_words])
    return ret

# 반복되는 문자 처리
repeat_replacer = RepeatReplacer()
def repeat_replacing(doc):
    ret=[]
    for sent in doc:
        sent_ret = []
        for word in sent:
            sent_ret.append(repeat_replacer.replace(word))
        ret.append(sent_ret)
    return ret

# %%
# %%time
for df, name in zip((train, test, validation),('train_text', 'test_text', 'validation_text')):
    globals()[name] = df['Text'].values.tolist()
    for foo in (lower_casing, reg_exp_replacer.replace, sent_tokenize, word_tokenizing, punctuation_replacing,stop_words_replacing,repeat_replacing):
        globals()[name] = list(map(foo, globals()[name]))
# Out:
# Wall time: 13.8 s

# %%
train_text
# Out:
# [[['zoe',
#    'telford',
#    'played',
#    'police',
#    'officer',
#    'girlfriend',
#    'simon',
#    'magie'],
#   ['dumped',
#    'simon',
#    'final',
#    'episode',
#    'series',
#    '1',
#    'slept',
#    'jenny',
#    'seen'],
#   ['phoebe',
#    'thomas',
#    'played',
#    'cheryl',
#    'casidy',
#    'pauline',
#    'friend',
#    'also',
#    'year',
#    '11',
#    'pupil',
#    'simon',
#    'class'],
#   ['dumped',
#    'boyfriend',
#    'following',
#    'simon',
#    'advice',
#    'would',
#    'sex',
#    'later',
#    'realised',
#    'due',
#    'catching',
#    'crabs',
#    'friend',
#    'pauline']],
#  [['grew',
#    'evanston',
#    'illinois',
#    'second',
#    'oldest',
#    'five',
#    'children',
#    'including',
#    'brothers',
#    'fred',
#    'gordon',
#    'sisters',
#    'marge',
#    'peppy',
#    'marilyn'],
#   ['high',
#    'school',
#    'days',
#    'spent',
#    'new',
#    'trier',
#    'high',
#    'school',
#    'winetka',
#    'illinois'],
#   ['mackenzie',
#    'studied',
#    'bernard',
#    'leach',
#    '1949',
#    '1952',
#    'simple',
#    'whelthrown',
#    'functional',
#    'pottery',
#    'heavily',
#    'influenced',
#    'oriental',
#    'aesthetic',
#    'shoji',
#    'hamada',
#    'kanjiro',
#    'kawai']],
#  [['reelected',
#    'congress',
#    'resigned',
#    '190',
#    'accept',
#    'post',
#    'ambassador',
#    'brazil'],
#   ['de',
#    'la',
#    'sota',
#    'ran',
#    'governor',
#    'crdoba',
#    '191',
#    'defeated',
#    'governor',
#    'angeloz',
#    '15',
#    'latter',
#    'setback',
#    'significant',
#    'cost',
#    'de',
#    'la',
#    'sota',
#    'much',
#    'support',
#    'within',
#    'justicialist',
#    'party',
#    'flush',
#    'victory',
#    '191',
#    'midterms',
#    'leading',
#    'president',
#    'carlos',
#    'menem',
#    'endorsement',
#    'separate',
#    'party',
#    'list',
#    'crdoba',
#    '193',
#    'midterm',
#    'elections',
#    'de',
#    'la',
#    'sota',
#    'failure',
#    'regain',
#    'seat',
#    'congress']],
#  [['current',
#    'members',
#    'crime',
#    'also',
#    'performed',
#    'san',
#    'francisco',
#    'band',
#    'name',
#    'remote',
#    'viewers'],
#   ['strike',
#    'published',
#    'two',
#    'works',
#    'fiction',
#    'recent',
#    'years',
#    'ports',
#    'hell',
#    'listed',
#    'rock',
#    'roll',
#    'hall',
#    'fame',
#    'library',
#    'loud',
#    'humming',
#    'sound',
#    'came'],
#   ['rank',
#    'produced',
#    'numerous',
#    'films',
#    'real',
#    'name',
#    'henry',
#    'rosenthal',
#    'including',
#    'hit',
#    'devil',
#    'daniel',
#    'johnston']],
#  [['santa',
#    'fe',
#    'opera',
#    'debut',
#    '205',
#    'nuria',
#    'revised',
#    'edition',
#    'golijov',
#    'ainadamar'],
#   ['sang', 'subsequent', 'deutsche', 'gramophon', 'recording', 'opera'],
#   ['opera',
#    'doctor',
#    'atomic',
#    'adams',
#    'rewrote',
#    'role',
#    'kitty',
#    'oppenheimer',
#    'originally',
#    'mezosoprano',
#    'role',
#    'soprano',
#    'voice',
#    'rivera',
#    'sang',
#    'rewritten',
#    'part',
#    'kitty',
#    'oppenheimer',
#    'lyric',
#    'opera',
#    'chicago',
#    'de',
#    'nederlandse',
#    'opera',
#    'metropolitan',
#    'opera',
#    '207',
#    'since',
#    'sung',
#    'several',
#    'parts',
#    'roles',
#    'john',
#    'adams',
#    'works',
#    'including',
#    'soprano',
#    'part',
#    'el',
#    'nio',
#    'role',
#    'kumudha',
#    'flowering',
#    'tree',
#    'peter',
#    'selars',
#    'production',
#    'new',
#    'crowned',
#    'hope',
#    'festival',
#    'vienna']],
#  [['sandra', 'collins', 'american', 'dj'],
#   ['got',
#    'start',
#    'west',
#    'coast',
#    'us',
#    'phoenix',
#    'arizona',
#    'residencies',
#    'los',
#    'angeles',
#    'eventually',
#    'moved',
#    'towards',
#    'trance'],
#   ['used', 'american', 'producers', 'give', 'unique', 'sound'],
#   ['collins',
#    'performed',
#    'estimated',
#    '80',
#    'people',
#    'first',
#    'night',
#    'wodstock',
#    '99',
#    'first',
#    'female',
#    'dj',
#    'featured',
#    'tranceport',
#    'series',
#    'influential',
#    'recordings'],
#   ['recently',
#    'released',
#    'two',
#    'cd',
#    'mixes',
#    'paul',
#    'oakenfold',
#    'perfecto',
#    'label']],
#  [['reb',
#    'chaim',
#    'yakov',
#    'wife',
#    'sister',
#    'rabbi',
#    'moishe',
#    'sternbuch',
#    'wife',
#    'rabbi',
#    'meshulam',
#    'dovid',
#    'soloveitchik',
#    'making',
#    'two',
#    'rabbis',
#    'uncles'],
#   ['reb',
#    'asher',
#    'brother',
#    'rabbi',
#    'shlomo',
#    'arieli',
#    'author',
#    'critical',
#    'edition',
#    'novalae',
#    'rabbi',
#    'akiva',
#    'eiger'],
#   ['marriage',
#    'rabbi',
#    'arieli',
#    'studied',
#    'ponevezh',
#    'yeshiva',
#    'headed',
#    'rabbi',
#    'shmuel',
#    'rozovsky',
#    'later',
#    'studied',
#    'fatherinlaw',
#    'mirer',
#    'yeshiva']],
#  [['slant',
#    'magazine',
#    'sal',
#    'cinquemani',
#    'viewed',
#    'album',
#    'formulaic',
#    'competently',
#    'often',
#    'frustratingly',
#    'artist',
#    'still',
#    'seems',
#    'capable',
#    'much'],
#   ['greg',
#    'kot',
#    'chicago',
#    'tribune',
#    'perceived',
#    'formula',
#    'production',
#    'hack',
#    'songwriting',
#    'complimented',
#    'pink',
#    'personality',
#    'handful',
#    'worthy',
#    'tracks'],
#   ['list',
#    'barnes',
#    'noble',
#    'review',
#    'robert',
#    'christgau',
#    'named',
#    'truth',
#    'love',
#    'fourth',
#    'best',
#    'album',
#    '2012']],
#  [['father',
#    'englishman',
#    'rank',
#    'culture',
#    'mother',
#    'free',
#    'woman',
#    'color',
#    'described',
#    'lightskined'],
#   ['mary',
#    'six',
#    'mother',
#    'sent',
#    'alexandria',
#    'part',
#    'district',
#    'columbia',
#    'attend',
#    'school'],
#   ['living', 'aunt', 'mary', 'paine', 'kelsey', 'studied', 'ten', 'years']],
#  [['shaftesbury',
#    'uk',
#    'partners',
#    'production',
#    'series',
#    'british',
#    'broadcaster',
#    'uktv',
#    'international',
#    'distributor',
#    'itv',
#    'studios',
#    'global',
#    'entertainment',
#    'interested',
#    'additional',
#    'seasons'],
#   ['christina',
#    'jenings',
#    'approached',
#    'kirstine',
#    'stewart',
#    'executive',
#    'vicepresident',
#    'cbc',
#    'english',
#    'services',
#    'continuing',
#    'series',
#    'felt',
#    'home',
#    'cbc',
#    'made',
#    'absolute',
#    'sense']],
#  [['wiliam',
#    'shatner',
#    'portraying',
#    'writer',
#    'mark',
#    'twain',
#    'special',
#    'christmas',
#    'episode',
#    'included',
#    'appearances',
#    'ed',
#    'asner',
#    'brendan',
#    'coyle',
#    'kelly',
#    'rowan',
#    'television',
#    'news',
#    'anchor',
#    'peter',
#    'mansbridge',
#    'episode',
#    'featured',
#    'david',
#    'onley',
#    'lieutenant',
#    'governor',
#    'ontario',
#    'time',
#    'production',
#    'appearing',
#    'forerunner',
#    'oliver',
#    'mowat',
#    'two',
#    'different',
#    'episodes',
#    'former',
#    'dragons',
#    'den',
#    'investors',
#    'arlene',
#    'dickinson',
#    'david',
#    'chilton',
#    'guest',
#    'starred']],
#  [['maternal',
#    'greatgrandfather',
#    'henry',
#    'percy',
#    '4th',
#    'earl',
#    'northumberland',
#    'whose',
#    'wife',
#    'maud',
#    'herbert',
#    'countess',
#    'northumberland'],
#   ['maternal',
#    'grandmother',
#    'daughter',
#    'sir',
#    'robert',
#    'spencer',
#    'eleanor',
#    'beaufort'],
#   ['eleanor',
#    'daughter',
#    'edmund',
#    'beaufort',
#    '2nd',
#    'duke',
#    'somerset',
#    'eleanor',
#    'beauchamp'],
#   ['granddaughter',
#    'richard',
#    'de',
#    'beauchamp',
#    '13th',
#    'earl',
#    'warwick',
#    'elizabeth',
#    'berkeley']],
#  [['kilian',
#    '1978',
#    '79',
#    'assistant',
#    'district',
#    'attorney',
#    'brunswick',
#    'judicial',
#    'circuit',
#    '1979',
#    '80',
#    'practicing',
#    'attorney',
#    'glyn',
#    'county',
#    '1980',
#    '90',
#    'williams',
#    'elected',
#    'superior',
#    'court',
#    'judge',
#    '190',
#    'taking',
#    'bench',
#    '191',
#    'november',
#    '2010',
#    'williams',
#    'competed',
#    'mary',
#    'helen',
#    'moses',
#    'recent',
#    'bid',
#    'reelection']],
#  [['arta',
#    'driver',
#    'vitantonio',
#    'liuzi',
#    'replaced',
#    'former',
#    'mugen',
#    'driver',
#    'tomoki',
#    'nojiri',
#    'disappointing',
#    'season',
#    'last',
#    'year'],
#   ['years',
#    'real',
#    'racing',
#    'toshihiro',
#    'kaneishi',
#    'drive',
#    'season',
#    'replaced',
#    'former',
#    'team',
#    'kunimitsu',
#    'driver',
#    'hideki',
#    'mutoh'],
#   ['kazuki',
#    'nakajima',
#    'like',
#    'oliver',
#    'jarvis',
#    'return',
#    'focus',
#    'lmp1',
#    'drive',
#    '2015',
#    'world',
#    'endurance',
#    'championship']],
#  [['twenty',
#    'years',
#    'ago',
#    'lorenzo',
#    'uribe',
#    'discovered',
#    'true',
#    'love',
#    'maria',
#    'herera',
#    'began',
#    'romance'],
#   ['lorenzo', 'rich', 'married', 'young', 'son', 'lautaro'],
#   ['maria', 'poor', 'unknown', 'lorenzo', 'daughter', 'called', 'renata'],
#   ['maria',
#    'mother',
#    'gracia',
#    'wanted',
#    'daughter',
#    'catch',
#    'rich',
#    'man',
#    'costs',
#    'convinced',
#    'pregnancy',
#    'would',
#    'assure']],
#  [['colleague',
#    'department',
#    'run',
#    'erwin',
#    'frink',
#    'smith',
#    'also',
#    'collaborated',
#    'botanist',
#    'nelie',
#    'adalesa',
#    'brown'],
#   ['mculoch', 'born', 'cincinnati', 'ohio'],
#   ['daughter', 'robert', 'alma', 'tagart', 'ne', 'eveleth', 'mculoch'],
#   ['1898',
#    'studying',
#    'biology',
#    'florida',
#    'agricultural',
#    'college',
#    'appointed',
#    'head',
#    'library',
#    'part',
#    'george',
#    'smathers',
#    'libraries']],
#  [['maurice',
#    'customtailors',
#    'clothing',
#    'de',
#    'varze',
#    'credit',
#    'vicomte',
#    'unpaid',
#    'tailoring',
#    'bills',
#    'become',
#    'intolerable',
#    'maurice',
#    'travels',
#    'de',
#    'savignac',
#    'castle',
#    'collect',
#    'money',
#    'owed'],
#   ['way', 'confrontation', 'princese', 'jeanete'],
#   ['immediately', 'professes', 'love', 'haughtily', 'rejects'],
#   ['maurice',
#    'arrives',
#    'castle',
#    'gilbert',
#    'introduces',
#    'baron',
#    'courtelin',
#    'order',
#    'hide',
#    'truth',
#    'comte']],
#  [['198',
#    'race',
#    'suffered',
#    'abdominal',
#    'injury',
#    'absence',
#    'manager',
#    'bobby',
#    'brain',
#    'henan',
#    'awarded',
#    'crown',
#    'haku',
#    'july',
#    'rechristening',
#    'king',
#    'haku',
#    'even',
#    'though',
#    'randy',
#    'savage',
#    'tournament',
#    'point',
#    'ted',
#    'dibiase',
#    'would',
#    'also',
#    'win',
#    'tournament',
#    'storyline'],
#   ['race',
#    'eventually',
#    'returned',
#    'injury',
#    'briefly',
#    'feuded',
#    'king',
#    'haku',
#    'unable',
#    'regain',
#    'crown',
#    '1989',
#    'royal',
#    'rumble']],
#  [['rest',
#    'group',
#    'find',
#    'happened',
#    'case',
#    'decide',
#    'band',
#    'together',
#    'take',
#    'justin',
#    'beatdown',
#    'avenge',
#    'mentor'],
#   ['facing', 'trials', 'reach', 'final', 'match', 'comes', 'one', 'versus'],
#   ['mike',
#    'defeats',
#    'zack',
#    'justin',
#    'injures',
#    'tim',
#    'restroom',
#    'thus',
#    'eliminating',
#    'tournament']],
#  [['30',
#    'july',
#    '196',
#    'ramsey',
#    'promise',
#    'fulfilled',
#    'england',
#    'became',
#    'world',
#    'champions',
#    'beating',
#    'west',
#    'germany',
#    'thrilling',
#    'final'],
#   ['lot', 'ramsey', 'tactics', 'decisions', 'proved', 'worth', 'final'],
#   ['ramsey',
#    'came',
#    'pressure',
#    'restore',
#    'fitagain',
#    'jimmy',
#    'greaves',
#    'side',
#    'stuck',
#    'guns',
#    'kept',
#    'faith',
#    'greaves',
#    'replacement',
#    'geof',
#    'hurst',
#    'vindicated',
#    'ramsey',
#    'judgement',
#    'scoring',
#    'hatrick',
#    '4',
#    '2',
#    'win',
#    'extra',
#    'time',
#    'wembley'],
#   ['filling',
#    'side',
#    'good',
#    'balance',
#    'experience',
#    'youth',
#    'proved',
#    'vital',
#    'gruelling',
#    'final',
#    'went',
#    'extra',
#    'time']],
#  [['ben',
#    'severson',
#    'pioneer',
#    'sport',
#    'bodyboarding',
#    'sandy',
#    'beach',
#    'local'],
#   ['oahu',
#    'lifeguard',
#    'former',
#    'rival',
#    'mike',
#    'stewart',
#    '15',
#    'years',
#    'ben',
#    'fast',
#    'perfectly',
#    'trained',
#    'precise',
#    'prone',
#    'rider',
#    'excels',
#    'tube',
#    'riding'],
#   ['quickly',
#    'gained',
#    'recognition',
#    'winning',
#    'world',
#    'title',
#    'beginning',
#    'career']],
#  [['device',
#    'allowed',
#    'continue',
#    'racing',
#    'career',
#    'barber',
#    'pro',
#    'series',
#    'grand',
#    'american',
#    'road',
#    'racing',
#    'championship',
#    'eventually',
#    'enter',
#    '24',
#    'hours',
#    'daytona',
#    '209',
#    'kurt',
#    'worked',
#    'various',
#    'charities',
#    'organizations',
#    'raise',
#    'awareness',
#    'donations',
#    'childhood',
#    'cancer'],
#   ['since',
#    'overcoming',
#    'illness',
#    'kurt',
#    'teamed',
#    'paul',
#    'newman',
#    'hole',
#    'wall',
#    'gang',
#    'camp',
#    'one',
#    'lap',
#    'america',
#    'fundraising',
#    'events']],
#  [['meeting',
#    'went',
#    'little',
#    'differently',
#    'many',
#    'predicted',
#    'laid',
#    'groundwork',
#    'mage',
#    'sell',
#    'inquirer',
#    'vnu',
#    'business',
#    'publications',
#    'later',
#    'year'],
#   ['mage',
#    'remained',
#    'editor',
#    'inquirer',
#    'february',
#    '208',
#    'left',
#    'pursue',
#    'publishing',
#    'ventures'],
#   ['1960s',
#    'mage',
#    'experimented',
#    'occult',
#    'teachings',
#    'hermetic',
#    'order',
#    'golden',
#    'dawn',
#    'keneth',
#    'grant',
#    'typhonian',
#    'order',
#    'leading',
#    'work',
#    'cited',
#    'grant',
#    'books',
#    'cults',
#    'shadow',
#    'nightside',
#    'eden',
#    'outside',
#    'circles',
#    'time']],
#  [['louis',
#    'mcneil',
#    'begin',
#    'publishing',
#    'career',
#    'selling',
#    'short',
#    'poems',
#    'saturday',
#    'evening',
#    'post'],
#   ['1931', 'first', 'collection', 'mountain', 'white', 'published'],
#   ['went', 'publish', 'six', 'collections'],
#   ['1980s',
#    'mcneil',
#    'literary',
#    'reputation',
#    'reestablished',
#    'poet',
#    'magie',
#    'anderson',
#    'edited',
#    'mcneil',
#    'memoir',
#    'university',
#    'pittsburgh',
#    'press',
#    'well',
#    'new',
#    'selected',
#    'poems',
#    '191',
#    '1979',
#    'thengovernor',
#    'jay',
#    'rockefeller',
#    'named',
#    'west',
#    'virginia',
#    'poet',
#    'laureate']],
#  [['initial',
#    'ambition',
#    'become',
#    'cultured',
#    'private',
#    'secretary',
#    'working',
#    'highest',
#    'cultural',
#    'circles'],
#   ['month',
#    'later',
#    'michigan',
#    'league',
#    'building',
#    'opened',
#    'serving',
#    'coeds',
#    'michigan',
#    'union',
#    'served',
#    'men'],
#   ['hartwig',
#    'began',
#    'secretarial',
#    'work',
#    'dr',
#    'margaret',
#    'bell',
#    'head',
#    'women',
#    'physical',
#    'education',
#    'spotted']],
#  [['broadly',
#    'positive',
#    'though',
#    'stopped',
#    'short',
#    'naming',
#    'one',
#    'ayckbourn',
#    'best'],
#   ['michael',
#    'bilington',
#    'guardian',
#    'wrote',
#    'dramatists',
#    'history',
#    'painted',
#    'devastating',
#    'picture',
#    'emotional',
#    'damage',
#    'wrought',
#    'bullying',
#    'men',
#    'described',
#    'martin',
#    'misguided',
#    'affection',
#    'girlfriends',
#    'instant',
#    'image',
#    'grisly',
#    'inheritance']],
#  [['conie',
#    'onesided',
#    'conversation',
#    'gives',
#    'praises',
#    'late',
#    'brother',
#    'gordon'],
#   ['seem',
#    'mind',
#    'spent',
#    'childhood',
#    'shadow',
#    'brother',
#    'blatantly',
#    'family',
#    'favourite',
#    'given',
#    'support',
#    'never'],
#   ['although',
#    'beth',
#    'quietly',
#    'agrees',
#    'conie',
#    'idea',
#    'idyllic',
#    'marriage',
#    'gordon',
#    'expresses',
#    'subtle',
#    'annoyance',
#    'conie',
#    'idea',
#    'whole',
#    'family',
#    'look',
#    'first',
#    'christmas',
#    'alone',
#    'conie',
#    'hints',
#    'selfpity',
#    'help',
#    'either']],
#  [['list', 'episodes', 'mtv', 'show', 'bully', 'beatdown'],
#   ['first',
#    'aired',
#    '22',
#    'march',
#    '209',
#    'victim',
#    'series',
#    'premier',
#    'named',
#    'alan',
#    'man',
#    'gets',
#    'bullied',
#    'bigger',
#    'younger',
#    'brother'],
#   ['tape',
#    'alan',
#    'explains',
#    'ryan',
#    'gets',
#    'away',
#    'bullying',
#    'family',
#    'favorite']],
#  [['meet', 'mike', 'shortest', 'bully', 'appear', 'show'],
#   ['stands',
#    '5',
#    '4',
#    'bronx',
#    'gym',
#    'rat',
#    'makes',
#    'life',
#    'miserable',
#    'victims',
#    'lorenzo',
#    'joey'],
#   ['mayhem',
#    'miller',
#    'brings',
#    'ma',
#    'fighter',
#    'edie',
#    'alvarez',
#    'record',
#    '22',
#    'wins',
#    '2',
#    'losses',
#    'teach',
#    'lesson']],
#  [['six',
#    'months',
#    'experience',
#    'belt',
#    'paul',
#    'niagara',
#    'district',
#    'bantamweight',
#    'amateur',
#    'title',
#    'national',
#    'au',
#    'tournament',
#    'boston',
#    'empire',
#    'state',
#    'amateur',
#    'championship',
#    'within',
#    'three',
#    'month',
#    'span',
#    '1927',
#    'august',
#    '1',
#    '1927',
#    'paul',
#    'knocked',
#    'fredie',
#    'griffiths',
#    'four',
#    'rounds',
#    'first',
#    'professional',
#    'fight']],
#  [['nicholas',
#    'rogers',
#    'tarabas',
#    'role',
#    'also',
#    'caused',
#    'problems',
#    'declared',
#    'audition',
#    'able',
#    'ride',
#    'horses',
#    'soon',
#    'shooting',
#    'began',
#    'could',
#    'even',
#    'mount',
#    'horse'],
#   ['soon',
#    'realized',
#    'also',
#    'good',
#    'acting',
#    'bava',
#    'said',
#    'scene',
#    'rogers',
#    'say',
#    'love',
#    'make',
#    'three',
#    'shots',
#    'combine',
#    'later'],
#   ['also',
#    'injured',
#    'set',
#    'taken',
#    'hospital',
#    'still',
#    'wearing',
#    'costume']],
#  [['confronted',
#    'xelesia',
#    'explains',
#    'dark',
#    'magic',
#    'within',
#    'allow',
#    'fall',
#    'love',
#    'soon',
#    'tries',
#    'kiss',
#    'one',
#    'desires',
#    'transformed',
#    'beast',
#    'devour'],
#   ['fantaghir',
#    'esmeralda',
#    'continue',
#    'journey',
#    'reunited',
#    'lightning',
#    'bolt',
#    'new',
#    'plan',
#    'track',
#    'tarabas'],
#   ['decide',
#    'resurrect',
#    'black',
#    'witch',
#    'destroyed',
#    'previous',
#    'film',
#    'hold',
#    'heart',
#    'hostage',
#    'promising',
#    'give',
#    'back',
#    'heart',
#    'helps',
#    'find',
#    'tarabas']],
#  [['christine',
#    'eventually',
#    'got',
#    'street',
#    'promoted',
#    'miami',
#    'modes',
#    'butted',
#    'heads',
#    'elsie',
#    'dot',
#    'like',
#    'way',
#    'used',
#    'newfound',
#    'authority'],
#   ['christine', 'transferred', 'moved', 'weatherfield', 'good'],
#   ['christine',
#    'sent',
#    'telegram',
#    'congratulate',
#    'elsie',
#    'steve',
#    'tanner',
#    'wedding',
#    'day',
#    '1967',
#    '1984',
#    'elsie',
#    'tanner',
#    'informed',
#    'ken',
#    'barlow',
#    'christine',
#    'died',
#    'liver',
#    'failure',
#    'becoming',
#    'alcoholic',
#    'late',
#    '1970s'],
#   ['never', 'mentioned']],
#  [['eventually',
#    'overheard',
#    'ofbuton',
#    'code',
#    'monster',
#    'threwilied',
#    'seth',
#    'proceeded',
#    'free'],
#   ['literally',
#    'took',
#    'heads',
#    'television',
#    'mogul',
#    'software',
#    'billionaire',
#    'coconspirator'],
#   ['also',
#    'saved',
#    'friend',
#    'angela',
#    'spica',
#    'engineer',
#    'killed',
#    'man',
#    'abusing',
#    'angela'],
#   ['originally',
#    'drawn',
#    'flatchested',
#    'plot',
#    'point',
#    'series',
#    'rapidly',
#    'developed',
#    'pronounced',
#    'archetypal',
#    'superheroine',
#    'bust',
#    'size']],
#  [['kevin',
#    'john',
#    'coyne',
#    'country',
#    'universe',
#    'gave',
#    'song',
#    'b',
#    'rating',
#    'saying',
#    'breakup',
#    'good',
#    'anybody',
#    'believe',
#    'keith',
#    'capable',
#    'turning',
#    'weak',
#    'vocal',
#    'performance'],
#   ['bobby',
#    'peacock',
#    'roughstock',
#    'gave',
#    'song',
#    '35',
#    'rating',
#    'saying',
#    'production',
#    'looser',
#    'funkier',
#    'keith',
#    'songs'],
#   ['goes',
#    'say',
#    'contrasts',
#    'downbeat',
#    'lyrics',
#    'fairly',
#    'standard',
#    'brokenheart',
#    'song']],
#  [['elected',
#    'following',
#    'conviction',
#    'fraud',
#    'charges',
#    'part',
#    'broad',
#    'scandal',
#    'involving',
#    'former',
#    'chairman',
#    'glenn',
#    'marshall',
#    'associated',
#    'jack',
#    'abramof',
#    'indian',
#    'lobbying',
#    'scandal'],
#   ['cromwell',
#    'election',
#    'administration',
#    'criticized',
#    'tribe',
#    'members',
#    'alleging',
#    'election',
#    'financial',
#    'improprieties'],
#   ['however',
#    'cromwell',
#    'successfully',
#    'gained',
#    'financial',
#    'backing',
#    'tribe',
#    'casino',
#    'development',
#    'effort',
#    'malaysian',
#    'billionaire',
#    'lim',
#    'goh',
#    'tong',
#    'kien',
#    'huat',
#    'realty',
#    'arm',
#    'genting',
#    'group',
#    'cromwell',
#    'also',
#    'successfully',
#    'hired',
#    'former',
#    'us',
#    'representative',
#    'bill',
#    'delahunt',
#    'lobby',
#    'behalf',
#    'tribe']],
#  [['1650',
#    'started',
#    'career',
#    'advisor',
#    'ministerium',
#    'finances',
#    'den',
#    'hag'],
#   ['became',
#    'minister',
#    'went',
#    'back',
#    'amsterdam',
#    'took',
#    'place',
#    'sort',
#    'chairing',
#    'mayor',
#    'city'],
#   ['death',
#    'brother',
#    'cornelis',
#    'de',
#    'graef',
#    'became',
#    'strong',
#    'leader',
#    'republicans'],
#   ['held', 'position', 'rampjar']],
#  [['story',
#    'echoes',
#    'helen',
#    'keller',
#    'beteridge',
#    'teacher',
#    'roberta',
#    'reid',
#    'fingerspelled',
#    'words',
#    'pupil',
#    'hand',
#    'beteridge',
#    'made',
#    'connection',
#    'words',
#    'spelled',
#    'objects',
#    'touching'],
#   ['breakthrough',
#    'came',
#    'reid',
#    'spelled',
#    'word',
#    'shoe',
#    'placing',
#    'shoe',
#    'alice',
#    'hand'],
#   ['education',
#    'progressed',
#    'rapidly',
#    'short',
#    'months',
#    'knew',
#    '200',
#    'nouns',
#    'several',
#    'verbs',
#    'including',
#    'run',
#    'jump',
#    'laugh',
#    'soon',
#    'began',
#    'learning',
#    'read',
#    'braille']],
#  [['recurring', 'injuries', 'kept', 'andrev', 'competing', 'several', 'years'],
#   ['injured',
#    'back',
#    'training',
#    'quads',
#    'forced',
#    'leave',
#    'skating',
#    '205',
#    'compete',
#    '205206',
#    '206207',
#    'seasons'],
#   ['andrev',
#    'returned',
#    'competition',
#    '207208',
#    'season',
#    'coached',
#    'detroit',
#    'calaghan'],
#   ['placed', '8th', '208', 'canadian', 'championships']],
#  [['postmaster',
#    'new',
#    'orleans',
#    'december',
#    '19',
#    '1843',
#    'april',
#    '18',
#    '1849',
#    'served',
#    'delegate',
#    'democratic',
#    'national',
#    'conventions',
#    '184',
#    '1852',
#    '1856',
#    '1860',
#    'penn',
#    'elected',
#    'democrat',
#    'thirtyfirst',
#    'congress',
#    'fill',
#    'vacancy',
#    'caused',
#    'death',
#    'john',
#    'h',
#    'harmanson'],
#   ['reelected',
#    'thirtysecond',
#    'congress',
#    'served',
#    'december',
#    '30',
#    '1850',
#    'march',
#    '3',
#    '1853']],
#  [['karl',
#    'philip',
#    'frst',
#    'zu',
#    'schwarzenberg',
#    'charles',
#    'philip',
#    'prince',
#    'schwarzenberg',
#    'april',
#    '18',
#    '171',
#    'october',
#    '15',
#    '1820',
#    'austrian',
#    'field',
#    'marshal'],
#   ['karl',
#    'philip',
#    'born',
#    'vienna',
#    'son',
#    'johan',
#    'nepomuk',
#    'anton',
#    'schwarzenberg',
#    'marie',
#    'eleonore',
#    'countess',
#    'tingenwalerstein'],
#   ['entered',
#    'imperial',
#    'cavalry',
#    '178',
#    'fought',
#    '1789',
#    'lacy',
#    'loudon',
#    'turks',
#    'distinguished',
#    'bravery',
#    'became',
#    'major',
#    '1792']],
#  [['1872',
#    'elected',
#    'house',
#    'commons',
#    'one',
#    'two',
#    'representatives',
#    'tamworth',
#    'seat',
#    'held',
#    '1878',
#    'sat',
#    'stafordshire',
#    'north',
#    '180',
#    'lost',
#    'seat'],
#   ['unsuccessfully',
#    'contested',
#    'preston',
#    '182',
#    'seat',
#    '185',
#    'liberal',
#    'stay',
#    'power',
#    '1892',
#    '1895',
#    'hanbury',
#    'vigorous',
#    'critic',
#    'wiliam',
#    'ewart',
#    'gladstone',
#    'second',
#    'home',
#    'rule',
#    'bill',
#    'financial',
#    'perspective'],
#   ['conservatives',
#    'came',
#    'power',
#    '1895',
#    'lord',
#    'salisbury',
#    'appointed',
#    'financial',
#    'secretary',
#    'treasury',
#    'sworn',
#    'privy',
#    'council']],
#  [['impressed',
#    'beauty',
#    'warrior',
#    'skills',
#    'fact',
#    'able',
#    'locate',
#    'promoted',
#    'position',
#    'similar',
#    'later',
#    'held',
#    'halfsister',
#    'talia'],
#   ['right', 'hand', 'associate', 'accompanies', 'adventures'],
#   ['ra',
#    'impressed',
#    'abilities',
#    'even',
#    'allows',
#    'nyssa',
#    'use',
#    'lazarus',
#    'pits'],
#   ['like',
#    'sister',
#    'talia',
#    'nyssa',
#    'eventually',
#    'becomes',
#    'disenchanted',
#    'ra',
#    'genocidal',
#    'plans',
#    'cleanse',
#    'earth',
#    'disassociates',
#    'father',
#    'sometime',
#    'early',
#    '20th',
#    'century']],
#  [['among',
#    '3',
#    'limpido',
#    'limpio',
#    'se',
#    'non',
#    'te',
#    'sino',
#    'ti',
#    'dove',
#    'resto',
#    'solo',
#    'io',
#    'donde',
#    'quedo',
#    'solo',
#    'yo',
#    'completely',
#    'new',
#    'written',
#    'album',
#    'three',
#    'tracks',
#    'chosen',
#    'singles',
#    'album'],
#   ['first',
#    'single',
#    'album',
#    'limpido',
#    'limpio',
#    'included',
#    'solo',
#    'duet',
#    'versions',
#    'kylie',
#    'minogue'],
#   ['2',
#    'ramaya',
#    'paola',
#    'amateur',
#    'recordings',
#    'laura',
#    'pausini',
#    'singing',
#    'famous',
#    'song',
#    'ramaya',
#    'two',
#    'years',
#    'old',
#    'former',
#    'daughter',
#    'saying',
#    'word',
#    'mamma',
#    'mommy',
#    'first',
#    'time',
#    'latter']],
#  [['2014',
#    'dean',
#    'played',
#    'lead',
#    'role',
#    'long',
#    'road',
#    'south',
#    'alongside',
#    'michael',
#    'brandon',
#    'new',
#    'play',
#    'paul',
#    'minx'],
#   ['press',
#    'said',
#    'deans',
#    'performance',
#    'felicity',
#    'dean',
#    'playing',
#    'best',
#    'drunk',
#    'nightdress',
#    'since',
#    'lindsay',
#    'duncan',
#    'face'],
#   ['felicity',
#    'dean',
#    'carol',
#    'an',
#    'marks',
#    'play',
#    'standout',
#    'performance',
#    'quakes',
#    'stage',
#    'sliver',
#    'heels',
#    'brimming',
#    'morose',
#    'longing'],
#   []],
#  [['featurelength',
#    'documentary',
#    'traced',
#    'journey',
#    'song',
#    'hava',
#    'nagila',
#    'ukraine',
#    'youtube'],
#   ['released',
#    'theatrically',
#    'screened',
#    '80',
#    'jewish',
#    'film',
#    'festivals',
#    'hava',
#    'nagila',
#    'movie',
#    'either',
#    'opening',
#    'closing',
#    'night',
#    'half',
#    'festivals'],
#   ['director',
#    'dyana',
#    'taylor',
#    'film',
#    'grandmother',
#    'photographer',
#    'dorothea',
#    'lange',
#    'grab',
#    'hunk',
#    'lightning',
#    'aired',
#    'pbs',
#    'american',
#    'masters',
#    '2014',
#    'produced',
#    'grosman']],
#  [['movie', 'either', 'opening', 'closing', 'night', 'half', 'festivals'],
#   ['director',
#    'dyana',
#    'taylor',
#    'film',
#    'grandmother',
#    'photographer',
#    'dorothea',
#    'lange',
#    'grab',
#    'hunk',
#    'lightning',
#    'aired',
#    'pbs',
#    'american',
#    'masters',
#    '2014',
#    'produced',
#    'grosman'],
#   ['directed', 'beyond', '2015', 'producer', 'nancy', 'spielberg']],
#  [['episodes',
#    'focused',
#    'friendship',
#    'judge',
#    'rifkind',
#    'liberal',
#    'jew',
#    'judge',
#    'sims',
#    'conservative',
#    'lesbian',
#    'african',
#    'american',
#    'well',
#    'romance',
#    'bobby',
#    'cynthia',
#    'ramon',
#    'infidelity',
#    'wife',
#    'cassandra',
#    'j',
#    'potentially',
#    'corrupt',
#    'mob',
#    'ties',
#    'fatima',
#    'drug',
#    'addiction',
#    'rebecca',
#    'rifkind',
#    'estrangement',
#    'father',
#    'spiegelman',
#    'byrnes',
#    'political',
#    'scheming']],
#  [['alice', '19', 'kathlen', 'mary', '12', 'gertrude', '10', 'mabel', '7'],
#   ['1901',
#    'census',
#    'allen',
#    'living',
#    'fox',
#    'lane',
#    'leyland',
#    '2nd',
#    'wife',
#    'margaret',
#    'whittle',
#    'daughter',
#    'james',
#    'whittle',
#    'coachman',
#    'an',
#    'mills',
#    'married',
#    '190',
#    '18',
#    'years',
#    'junior']],
#  [['flurry',
#    'tale',
#    'oneact',
#    'operamusical',
#    'composed',
#    'rusty',
#    'mage',
#    'libretto',
#    'billy',
#    'aronson',
#    'originated',
#    'developed',
#    'directed',
#    'grethe',
#    'baret',
#    'holby'],
#   ['scored',
#    'piano',
#    'two',
#    'male',
#    'voices',
#    'tenor',
#    'bass',
#    'three',
#    'female',
#    'voices',
#    '2',
#    'sopranos',
#    '1',
#    'mezosoprano',
#    'comic',
#    'plot',
#    'revolves',
#    'around',
#    'young',
#    'girl',
#    'ema',
#    'harried',
#    'father',
#    'proclaims',
#    'disbelief',
#    'santa',
#    'claus',
#    'talking',
#    'snowmen']],
#  [['auditions',
#    'dancer',
#    'cheung',
#    'lai',
#    'yuen',
#    'better',
#    'income',
#    'chance',
#    'find',
#    'father',
#    'emperor'],
#   ['evergreen',
#    'mak',
#    'ko',
#    'yan',
#    'kiu',
#    'bolung',
#    'music',
#    'bureau',
#    'official',
#    'looks',
#    'cheung',
#    'lai',
#    'yuen'],
#   ['quarrel',
#    'mingbut',
#    'bolung',
#    'loses',
#    'memory',
#    'gets',
#    'half',
#    'face',
#    'burnt']],
#  [['may',
#    '19',
#    '192',
#    'couple',
#    'marriage',
#    'ceremomy',
#    'isabella',
#    'went',
#    'labor',
#    'quickly',
#    'gave',
#    'birth',
#    'brady',
#    'victor',
#    'black',
#    'named',
#    'honor',
#    'brady',
#    'family',
#    'isabella',
#    'father'],
#   ['black',
#    'family',
#    'happiness',
#    'shortlived',
#    'dr',
#    'carly',
#    'manning',
#    'informed',
#    'isabella',
#    'back',
#    'pain',
#    'result',
#    'advanced',
#    'pancreatic',
#    'cancer']],
#  [['1972',
#    'hening',
#    'broke',
#    'world',
#    'records',
#    '50m',
#    '10m',
#    'made',
#    'favourite',
#    'distances',
#    '1972',
#    'winter',
#    'olympics',
#    'sapporo'],
#   ['50m',
#    'race',
#    'sylvia',
#    'burka',
#    'olympics',
#    'hening',
#    'obstructed',
#    'crossing',
#    'burka',
#    'still',
#    'set',
#    'fastest',
#    'time',
#    'new',
#    'olympic',
#    'record',
#    '4370']],
#  [['decorate',
#    'palace',
#    'several',
#    'campaigns',
#    'montano',
#    'employed',
#    'greatest',
#    'artists',
#    'time',
#    'giovani',
#    'batista',
#    'zeloti',
#    'already',
#    'intervened',
#    'interiors',
#    'palladio',
#    'villa',
#    'emo',
#    'fanzolo',
#    'anselmo',
#    'canera',
#    'andrea',
#    'vicentino',
#    'stuccoes',
#    'entrusted',
#    'lorenzo',
#    'rubini',
#    'contemporaneously',
#    'executed',
#    'external',
#    'decorations',
#    'loggia',
#    'del',
#    'capitanio',
#    'death',
#    '1574',
#    'son',
#    'agostino']],
#  [['major',
#    'decision',
#    'society',
#    'engage',
#    'professional',
#    'conductor',
#    '1946',
#    'following',
#    'resignation',
#    'th',
#    'crowther',
#    'wiliam',
#    'res',
#    'took',
#    'post'],
#   ['onetime',
#    'student',
#    'felix',
#    'weingartner',
#    'former',
#    'violinist',
#    'hall',
#    'res',
#    'experienced',
#    'musician',
#    'quickly',
#    'became',
#    'firm',
#    'favourite',
#    'orchestra',
#    'audience',
#    'alike'],
#   ['appointment',
#    'marked',
#    'definite',
#    'turningpoint',
#    'orchestra',
#    'rise',
#    'present',
#    'eminence',
#    'one',
#    'country',
#    'leading',
#    'nonprofessional',
#    'orchestras',
#    'steady',
#    'assured']],
#  [['many', 'guests', 'european', 'native', 'invited'],
#   ['approach',
#    'may',
#    'frere',
#    'port',
#    'bhavnagar',
#    'colonel',
#    'barton',
#    'political',
#    'agent',
#    'major',
#    'wodhouse',
#    'assistant',
#    'political',
#    'agent',
#    'diwan',
#    'sahib',
#    'samaldas',
#    'went',
#    'steam',
#    'launch',
#    'brought',
#    'governor',
#    'party',
#    'ashore']],
#  [['classicist',
#    'john',
#    'h',
#    'darms',
#    'resident',
#    'director',
#    'american',
#    'academy',
#    'professor',
#    'school',
#    'classical',
#    'studies',
#    '197',
#    '1980',
#    '1980',
#    '1984',
#    'director',
#    'sophie',
#    'consagra',
#    'strengthened',
#    'academy',
#    'ties',
#    'roman',
#    'community',
#    'italian',
#    'government'],
#   ['tenure',
#    'president',
#    '198',
#    '2013',
#    'adele',
#    'chatfieldtaylor',
#    'helped',
#    'restore',
#    'academy',
#    'mckim',
#    'mead',
#    'white',
#    'building',
#    'cost',
#    '82',
#    'million',
#    'oversaw',
#    'capital',
#    'campaign',
#    'institution',
#    'endowment',
#    'grew',
#    '100',
#    'million']],
#  [['aleway',
#    'played',
#    '857',
#    'minutes',
#    '11',
#    'matches',
#    'including',
#    '9',
#    'starts'],
#   ['defence',
#    'conceded',
#    'total',
#    '5',
#    'goals',
#    'regular',
#    'season',
#    'finals'],
#   ['march',
#    '2016',
#    'aleway',
#    'melbourne',
#    'city',
#    'teammate',
#    'steph',
#    'catley',
#    'joined',
#    'nwsl',
#    'newest',
#    'expansion',
#    'club',
#    'orlando',
#    'pride'],
#   ['orlando',
#    'pride',
#    'coach',
#    'tom',
#    'sermani',
#    'gave',
#    'aleway',
#    'first',
#    'cap',
#    'australia',
#    'coach',
#    'matildas',
#    '2010']],
#  [['tom',
#    'offers',
#    'repair',
#    'car',
#    'days',
#    'free',
#    'science',
#    'classes',
#    'school'],
#   ['option',
#    'accepts',
#    'frank',
#    'offer',
#    'stay',
#    'tree',
#    'house',
#    'without',
#    'tom',
#    'knowledge'],
#   ['frank',
#    'begins',
#    'close',
#    'friendship',
#    'v',
#    'hoping',
#    'get',
#    'tom',
#    'become',
#    'attracted'],
#   ['tells',
#    'tom',
#    'problem',
#    'job',
#    'meaning',
#    'tutoring',
#    'ruse',
#    'thinks',
#    'means',
#    'prostitution']],
#  [['according',
#    'rolling',
#    'stone',
#    'interview',
#    'conducted',
#    '1985',
#    'lindsay',
#    'left',
#    'raiders',
#    'contractual',
#    'thing',
#    'agree',
#    'stopped'],
#   ['lindsay',
#    'continued',
#    'record',
#    'solo',
#    'singles',
#    'years',
#    'warner',
#    'bros',
#    'elka',
#    'greedy',
#    'records',
#    'retiring',
#    'performing',
#    'serve',
#    'head',
#    'r',
#    'united',
#    'artists',
#    'records'],
#   ['contributed',
#    'recordings',
#    'artists',
#    'gery',
#    'raferty',
#    'baker',
#    'street',
#    'keny',
#    'rogers',
#    'others']],
#  [['new',
#    'world',
#    'translation',
#    'places',
#    'comma',
#    'word',
#    'today',
#    'dividing',
#    'two',
#    'separate',
#    'phrases',
#    'tell',
#    'today',
#    'paradise'],
#   ['differs',
#    'standard',
#    'translations',
#    'verse',
#    'tell',
#    'today',
#    'paradise'],
#   ['based',
#    'scriptures',
#    'matthew',
#    '1240',
#    '2763',
#    'mark',
#    '831',
#    '931',
#    'witnesses',
#    'believe',
#    'jesus',
#    'expectation',
#    'would',
#    'bodily',
#    'resurrected',
#    'three',
#    'days',
#    'precluded',
#    'paradise',
#    'day',
#    'died']],
#  [['biographical', 'page', 'mcord', 'yahoo'],
#   ['states',
#    'via',
#    'role',
#    'naomi',
#    'actress',
#    'became',
#    'one',
#    'hollywood',
#    'top',
#    'young',
#    'starstowatch',
#    'series',
#    'premiered',
#    '5',
#    'million',
#    'viewers',
#    'worldwide'],
#   ['review',
#    'series',
#    'premiere',
#    'tom',
#    'gliato',
#    'people',
#    'magazine',
#    'stated',
#    'standout',
#    'analyne',
#    'mcord',
#    'badgirl',
#    'naomi',
#    'clark',
#    'striking',
#    'physically',
#    'almost',
#    'startling',
#    'somewhere',
#    'charlize',
#    'theron',
#    'courtney',
#    'love',
#    'conveys',
#    'mix',
#    'high',
#    'drama',
#    'meanness',
#    'litlegirl',
#    'selfpity',
#    'lot',
#    'fun']],
#  [['many',
#    'supporters',
#    'thirdparty',
#    'presidential',
#    'candidate',
#    'george',
#    'c',
#    'wallace',
#    'sr',
#    'voted',
#    'gurney',
#    'hence',
#    'provided',
#    'coalition',
#    'growing',
#    'republicans',
#    'florida',
#    'allied',
#    'declining',
#    'number',
#    'conservative',
#    'democrats'],
#   ['gurney',
#    'ran',
#    'record',
#    'included',
#    'votes',
#    'civil',
#    'rights',
#    'legislation',
#    'foreign',
#    'aid',
#    'expensive',
#    'boondoggle',
#    'war',
#    'poverty'],
#   ['futurepresident',
#    'george',
#    'w',
#    'bush',
#    'worked',
#    'traveling',
#    'aide',
#    'gurney',
#    'running',
#    'senate',
#    'florida']],
#  [['2010',
#    'diehl',
#    'bronze',
#    'medal',
#    'european',
#    'individual',
#    'championships',
#    'manchester',
#    'england',
#    'june',
#    '2010',
#    'claimed',
#    'european',
#    'tour',
#    'circuit',
#    'finals',
#    'gold',
#    'medal',
#    'beating',
#    'susan',
#    'egelstaf',
#    'final',
#    'three',
#    'sets'],
#   ['2010',
#    'also',
#    'saw',
#    'diehl',
#    'beat',
#    'current',
#    'world',
#    'champion',
#    'lu',
#    'lan',
#    'china',
#    'reach',
#    'semi',
#    'final',
#    'swiss',
#    'open',
#    'super',
#    'series'],
#   ['home', 'country', 'russia', '14', 'national', 'titles', '209']],
#  [['historical',
#    'octavia',
#    'minor',
#    'first',
#    'husband',
#    'gaius',
#    'claudius',
#    'marcelus',
#    'minor',
#    'bore',
#    'three',
#    'children',
#    'marcelus',
#    'claudia',
#    'marcela',
#    'major',
#    'claudia',
#    'marcela',
#    'minor',
#    'octavia',
#    'rome',
#    'married',
#    'nobleman',
#    'named',
#    'glabius',
#    'children']],
#  [['flag',
#    'convenience',
#    'rock',
#    'group',
#    'formed',
#    '1982',
#    'former',
#    'buzcocks',
#    'members',
#    'steve',
#    'digle',
#    'john',
#    'maher',
#    'along',
#    'bassist',
#    'dave',
#    'farrow',
#    'keyboard',
#    'player',
#    'dp'],
#   ['first',
#    'two',
#    'lineups',
#    'managed',
#    'writer',
#    'music',
#    'critic',
#    'michael',
#    'gray',
#    'shortly',
#    'personal',
#    'management',
#    'gery',
#    'raferty']],
#  [['revealed',
#    'misty',
#    'tabitha',
#    'still',
#    'alive',
#    'learns',
#    'tabitha',
#    'smokes',
#    'flirts',
#    'boys',
#    'loving',
#    'sweet',
#    'innocent',
#    'child',
#    'would',
#    'previously',
#    'thought'],
#   ['grace', 'mother', 'peter', 'granmy', 'tabitha'],
#   ['misty',
#    'often',
#    'annoyed',
#    'whether',
#    'way',
#    'wastes',
#    'misty',
#    'money',
#    'way',
#    'influencing',
#    'tabitha']],
#  [['meets', 'muthuvel', 'prabhu', 'innocent', 'youth', 'fall', 'love'],
#   ['rathnavel',
#    'r',
#    'p',
#    'viswam',
#    'brings',
#    'son',
#    'muthuvel',
#    'without',
#    'affections',
#    'treats',
#    'like',
#    'worker',
#    'mother',
#    'vadivu',
#    'vadivukarasi',
#    'loves'],
#   ['rathnavel',
#    'arranges',
#    'muthuvel',
#    'marriage',
#    'niece',
#    'muthuvel',
#    'nirmala',
#    'reveal',
#    'love',
#    'aranmanai',
#    'accepts',
#    'finally',
#    'marriage',
#    'sosai',
#    'help']],
#  [['196',
#    'made',
#    'professor',
#    'history',
#    'doctrine',
#    'manchester',
#    'university',
#    '1968',
#    '1973',
#    'professor',
#    'theology'],
#   ['following', 'retirement', 'cunlifejones', 'professor', 'emeritus'],
#   ['wife',
#    'maude',
#    'died',
#    '28',
#    'august',
#    '1989',
#    'cunlifejones',
#    'lived',
#    'margaret',
#    'elder',
#    'daughter',
#    'home',
#    'essex']],
#  [['cowrote', 'ten', 'thirteen', 'songs', 'album', 'standard', 'edition'],
#   ['harvey',
#    'mason',
#    'jr',
#    'served',
#    'creative',
#    'director',
#    'beautiful',
#    'cowrote',
#    'produced',
#    'number',
#    'songs'],
#   ['mauboy',
#    'exclusive',
#    'interview',
#    'melissa',
#    'doyle',
#    'darwin',
#    'broadcast',
#    'sunday',
#    'night',
#    '15',
#    'september',
#    '2013',
#    '26',
#    'september',
#    '2013',
#    'cohosted',
#    'foty',
#    'show',
#    'performed',
#    'medley',
#    'inescapable',
#    'end',
#    'earth',
#    'saturday',
#    'night']],
#  [['poor',
#    'receptions',
#    'disillusioned',
#    'murnau',
#    'quit',
#    'fox',
#    'journey',
#    'south',
#    'pacific'],
#   ['together',
#    'documentary',
#    'film',
#    'pioneer',
#    'robert',
#    'flaherty',
#    'murnau',
#    'travelled',
#    'bora',
#    'bora',
#    'realize',
#    'film',
#    'tabu',
#    '1931',
#    'flaherty',
#    'left',
#    'artistic',
#    'disputes',
#    'murnau',
#    'finish',
#    'movie']],
#  [['young',
#    'artist',
#    'berlin',
#    'elisabet',
#    'ney',
#    'sculpted',
#    'various',
#    'luminaries',
#    'city',
#    'including',
#    'jacob',
#    'grimm',
#    'cosima',
#    'liszt',
#    'alexander',
#    'von',
#    'humboldt'],
#   ['ney',
#    'patronized',
#    'naturalist',
#    'humboldt',
#    'sculptor',
#    'christian',
#    'rauch',
#    'diplomat',
#    'varnhagen',
#    'von',
#    'ense',
#    'three',
#    'died',
#    'late',
#    '1857',
#    'mid',
#    '1859',
#    'decided',
#    'travel',
#    'germany',
#    'search',
#    'new',
#    'notable',
#    'subjects']],
#  [['pinter',
#    'wrote',
#    'room',
#    'two',
#    'four',
#    'days',
#    '1957',
#    'depending',
#    'account',
#    'suggestion',
#    'friend',
#    'henry',
#    'woolf',
#    'production',
#    'part',
#    'postgraduate',
#    'program',
#    'directing',
#    'university',
#    'bristol',
#    'bristol',
#    'england'],
#   ['published',
#    'interviews',
#    'pinter',
#    'woolf',
#    'vary',
#    'describing',
#    'many',
#    'days',
#    'pinter',
#    'took',
#    'write',
#    'room'],
#   ['according',
#    'bilington',
#    'official',
#    'biography',
#    'harold',
#    'pinter',
#    'woolf',
#    'asked',
#    'pinter',
#    'write',
#    'play',
#    'letter',
#    'pinter',
#    'received',
#    'autumn',
#    '1956',
#    'newly',
#    'married',
#    'actress',
#    'vivien',
#    'merchant',
#    'middle',
#    'season',
#    'torquay',
#    'pinter',
#    'replied',
#    'could',
#    'possibly',
#    'deliver',
#    'anything',
#    'six',
#    'months']],
#  [['currently', 'wide', 'receivers', 'coach', 'bowling', 'green'],
#   ['doege', 'born', 'san', 'angelo', 'texas', 'randy', 'melinda', 'doege'],
#   ['one', 'younger', 'brother'],
#   ['randy',
#    'doege',
#    'coached',
#    'several',
#    'high',
#    'schools',
#    'west',
#    'texas',
#    'becoming',
#    'head',
#    'coach',
#    'crane',
#    'high',
#    'school',
#    '203',
#    'freshman',
#    'season',
#    '204',
#    'seth',
#    'doege',
#    'starting',
#    'quarterback',
#    'crane',
#    'high',
#    'school',
#    'led',
#    'golden',
#    'cranes',
#    'area',
#    'round',
#    'playoffs',
#    'loss',
#    'tuscola',
#    'jim',
#    'ned',
#    'indians',
#    'led',
#    'senior',
#    'quarterback',
#    'colt',
#    'mcoy']],
#  [['next',
#    'year',
#    'though',
#    'lieutenantcolonel',
#    'selected',
#    'sir',
#    'ralph',
#    'abercromby',
#    'quartermastergeneral',
#    'army',
#    'mediterranean',
#    'time',
#    'another',
#    'young',
#    'scotsman',
#    'john',
#    'hope',
#    'also',
#    'gain',
#    'fame',
#    'moore',
#    'retreat',
#    'nominated',
#    'adjutantgeneral'],
#   ['sir',
#    'ralph',
#    'placed',
#    'greatest',
#    'confidence',
#    'anstruther',
#    'mainly',
#    'report',
#    'visit',
#    'turkish',
#    'headquarters',
#    'turks',
#    'would',
#    'ready',
#    'long',
#    'time',
#    'could',
#    'use',
#    'sir',
#    'ralph',
#    'left',
#    'marmorice',
#    'bay',
#    'determined',
#    'act',
#    'alone']],
#  [['least', 'one', 'band', 'member', 'wrote', 'every', 'song', 'album'],
#   ['josh',
#    'osborne',
#    'shane',
#    'mcanaly',
#    'dan',
#    'huff',
#    'served',
#    'producers'],
#   ['almusic',
#    'reviewer',
#    'stephen',
#    'thomas',
#    'erlewine',
#    'rated',
#    'album',
#    '4',
#    '5',
#    'stars',
#    'comparing',
#    'sound',
#    'favorably',
#    'alabama',
#    'dwight',
#    'yoakam'],
#   ['also',
#    'stated',
#    'three',
#    'members',
#    'construct',
#    'sturdy',
#    'songs',
#    'shimmering',
#    'surface',
#    'match']],
#  [['helped',
#    'engineer',
#    'annexation',
#    'city',
#    'heavily',
#    'africanamerican',
#    'impoverished',
#    'samtown',
#    'subdivision',
#    'south',
#    'alexandria'],
#   ['neighborhood', 'named', 'white', 'developer', 'sam', 'jacobs'],
#   ['annexing',
#    'samtown',
#    'snyder',
#    'borrowing',
#    'page',
#    'earl',
#    'long',
#    'attempted',
#    'register',
#    'black',
#    'voters',
#    '1950s',
#    'anticipation',
#    'supporting',
#    'politically',
#    'future']],
#  [['may',
#    '2010',
#    'social',
#    'weather',
#    'stations',
#    'opinion',
#    'poll',
#    'akb',
#    'topped',
#    'survey',
#    '564',
#    'vote',
#    'equivalent',
#    'two',
#    'seats',
#    'beating',
#    'seasoned',
#    'partylist',
#    'election',
#    'contenders',
#    'buhay',
#    'hayan',
#    'yumabong',
#    'bayan',
#    'muna'],
#   ['however',
#    'akb',
#    'accused',
#    'kontra',
#    'daya',
#    'cheating',
#    'group',
#    'creation',
#    'president',
#    'gloria',
#    'macapagalaroyo',
#    'expand',
#    'base',
#    'allies',
#    'house',
#    'representatives',
#    'charge',
#    'akb',
#    'denied']],
#  [['following',
#    'unsuccessful',
#    'application',
#    'chair',
#    'mathematics',
#    'aberystwyth',
#    '1872',
#    'taught',
#    'training',
#    'college',
#    'carmarthen'],
#   ['finally',
#    'secured',
#    'professorship',
#    'aberystwyth',
#    '1879',
#    'held',
#    '1919',
#    'along',
#    'way',
#    'title',
#    'became',
#    'professor',
#    'mathematics',
#    'astronomy'],
#   ['genese',
#    'introduced',
#    'united',
#    'kingdom',
#    'ideas',
#    'hermann',
#    'grasman',
#    'advancing',
#    'use',
#    'vector',
#    'analysis'],
#   ['1941',
#    'book',
#    'calculus',
#    'extensions',
#    'henry',
#    'forder',
#    'published',
#    'numerous',
#    'examples',
#    'vector',
#    'analysis',
#    'taken',
#    'genese',
#    'posthumous',
#    'notes']],
#  [['1984',
#    'petersen',
#    'married',
#    'zina',
#    'nibley',
#    'daughter',
#    'hugh',
#    'nibley'],
#   ['four', 'children', 'reside', 'provo', 'utah'],
#   ['petersen',
#    'lecturer',
#    'honors',
#    'program',
#    'byu',
#    'english',
#    'humanities',
#    'departments',
#    'utah',
#    'valley',
#    'university',
#    'received',
#    'faculty',
#    'excellence',
#    'award',
#    '206',
#    'familial',
#    'relationship',
#    'hugh',
#    'nibley',
#    'petersen',
#    'authored',
#    '202',
#    'biography',
#    'hugh',
#    'nibley']],
#  [['series',
#    'finale',
#    'charlotte',
#    'harry',
#    'adopt',
#    'baby',
#    'girl',
#    'lily',
#    'china'],
#   ['movie',
#    'sex',
#    'city',
#    'harry',
#    'biological',
#    'baby',
#    'girl',
#    'name',
#    'rose'],
#   ['seen',
#    'episode',
#    '8',
#    'season',
#    '6',
#    'new',
#    'york',
#    'times',
#    'wedding',
#    'announcement',
#    'harry',
#    'marriage',
#    'indicates',
#    'charlotte',
#    'writer',
#    'editor',
#    'fashions',
#    'magazine',
#    'fact',
#    'mentioned',
#    'time',
#    'series',
#    'subsequent',
#    'movies',
#    'possible',
#    'merely',
#    'prop',
#    'error',
#    'rest',
#    'newspaper',
#    'paragraphs',
#    'taken',
#    'big',
#    'natasha',
#    'wedding',
#    'announcement',
#    'season',
#    '3']],
#  [['however',
#    'real',
#    'power',
#    'lies',
#    'philip',
#    'declared',
#    'commander',
#    'league',
#    'army'],
#   ['olympias',
#    'put',
#    'aside',
#    'husband',
#    'philip',
#    'ii',
#    'following',
#    'philip',
#    'marriage',
#    'girl',
#    'named',
#    'cleopatra',
#    'renamed',
#    'eurydice'],
#   ['son', 'alexander', 'effectively', 'disowned', 'philip', 'actions'],
#   ['philip', 'ii', 'ptolemy', 'along', 'companions', 'son', 'exiled']],
#  [['new',
#    'prime',
#    'minister',
#    'margaret',
#    'thatcher',
#    'described',
#    'kane',
#    'allegations',
#    'unfounded',
#    'parliament',
#    'consequence',
#    'wadel',
#    'inferred',
#    'journalist',
#    'report',
#    'concluded',
#    'kane',
#    'allegations',
#    'unfounded'],
#   ['wadel', 'married', 'wife', 'dorothy', '1940', 'died', '201']],
#  [['gained',
#    'first',
#    'representation',
#    'immediately',
#    '197',
#    'election',
#    'puri',
#    'ruing',
#    'elected',
#    'people',
#    'resources',
#    'awareness',
#    'party',
#    'joined',
#    'party'],
#   ['party',
#    'initially',
#    'supported',
#    'government',
#    'bill',
#    'skate',
#    'later',
#    'supported',
#    'government',
#    'mekere',
#    'morauta',
#    'ruing',
#    'made',
#    'minister',
#    'government']],
#  [['detective',
#    'roe',
#    'appears',
#    'reveals',
#    'patriarch',
#    'cannibal',
#    'family',
#    'father',
#    'leatherface',
#    'refers',
#    'gary'],
#   ['vanessa',
#    'never',
#    'escaped',
#    'hospital',
#    'room',
#    'one',
#    'family',
#    'sheds'],
#   ['roe',
#    'pulls',
#    'sheet',
#    'vanessa',
#    'head',
#    'daisy',
#    'beat',
#    'death',
#    'wrench']],
#  [['musical',
#    'style',
#    'essentially',
#    'tonal',
#    'evoking',
#    'work',
#    'period',
#    'setting',
#    'galops',
#    'marches',
#    'instrumental',
#    'interludes',
#    'highly',
#    'programatic',
#    'choral',
#    'ensembles',
#    'make',
#    'use',
#    'original',
#    'onomatopoeic',
#    'devices'],
#   ['music',
#    'treasure',
#    'island',
#    'adventurous',
#    'colorful',
#    'hornpipes',
#    'used',
#    'language',
#    'richly',
#    'chromatic',
#    'considerable',
#    'rhythmic',
#    'intensity'],
#   ['editorial', 'work', 'elkus', 'focused', 'music', 'charles', 'ives']],
#  [['later',
#    'day',
#    'announced',
#    'reapointment',
#    'paul',
#    'biyoghe',
#    'mba',
#    'prime',
#    'minister',
#    'made',
#    'announcement',
#    'personally',
#    'underline',
#    'importance',
#    'moment'],
#   ['according',
#    'bongo',
#    'biyoghe',
#    'mba',
#    'necessary',
#    'experience',
#    'managerial',
#    'competence',
#    'lead',
#    'us',
#    'next',
#    'stage',
#    'said',
#    'work',
#    'would',
#    'start',
#    'immediately']],
#  [['finally', 'tony', 'marries', 'anne', 'irks', 'daniel'],
#   ['soon',
#    'life',
#    'starts',
#    'disturbing',
#    'anne',
#    'finds',
#    'tony',
#    'actually',
#    'cheating',
#    'conman'],
#   ['tony', 'explain', 'became', 'conman', 'past', 'struggling', 'life'],
#   ['daniel', 'gets', 'killed', 'tony', 'tries', 'rape', 'anne']],
#  [['jrusalem',
#    '1847',
#    'paris',
#    'composed',
#    'giusepe',
#    'verdi',
#    'libretto',
#    'alphonse',
#    'royer',
#    'gustave',
#    'vaz',
#    'aroldo',
#    '1857',
#    'rimini',
#    'composed',
#    'giusepe',
#    'verdi',
#    'libretto',
# ...
#  [['high',
#    'point',
#    'show',
#    'came',
#    'christmas',
#    'season',
#    'paul',
#    'shannon',
#    'loaded',
#    'children',
#    'letters',
#    'santa',
#    'claus',
#    'rocket',
#    'launched',
#    'north',
#    'pole'],
#   ['santa', 'later', 'opened', 'letters', 'read', 'air'],
#   ['martin', 'main', 'character', 'series', 'baby', 'jefy'],
#   ['puppet',
#    'lost',
#    'one',
#    'point',
#    'production',
#    'negri',
#    'claims',
#    'martin',
#    'reacted',
#    'like',
#    'jefy',
#    'kidnapped'],
#   ['book',
#    'moe',
#    'howard',
#    'three',
#    'stooges',
#    'credited',
#    'paul',
#    'shannon',
#    'sparking',
#    'renewed',
#    'interest',
#    'stooges']],
#  [['violet',
#    'winifred',
#    'leslie',
#    'henry',
#    'anderson',
#    'blairgowrie',
#    'perthshire',
#    'daughter',
#    'isaac',
#    'henryanderson',
#    'katherine',
#    'blyth'],
#   ['father',
#    'solicitor',
#    'secretary',
#    'blairgowrie',
#    'golf',
#    'club',
#    'went',
#    'bankrupt',
#    '1904',
#    'left',
#    'family']],
#  [['mother',
#    'frances',
#    'antoinete',
#    'johnston',
#    'congressional',
#    'journalist',
#    'dramatic',
#    'critic',
#    'baltimore',
#    'sun',
#    'daughter',
#    'built',
#    'familiarity',
#    'washington',
#    'political',
#    'scene',
#    'becoming',
#    'official',
#    'white',
#    'house',
#    'photographer',
#    'harrison',
#    'cleveland',
#    'mckinley',
#    'tr',
#    'roosevelt',
#    'taft',
#    'presidential',
#    'administrations'],
#   ['johnston',
#    'also',
#    'photographed',
#    'famous',
#    'american',
#    'heiress',
#    'literary',
#    'salon',
#    'socialite',
#    'natalie',
#    'barney',
#    'paris',
#    'perhaps',
#    'famous',
#    'work',
#    'shown',
#    'selfportrait',
#    'liberated',
#    'new',
#    'woman',
#    'petticoats',
#    'showing',
#    'beer',
#    'stein',
#    'hand']],
#  [['another',
#    'famous',
#    'political',
#    'programme',
#    'host',
#    'raymond',
#    'wong',
#    'yuk',
#    'man',
#    'announced',
#    'decision',
#    'quit',
#    'programme',
#    '13',
#    'may',
#    'claiming',
#    'threat',
#    'family',
#    'safety'],
#   ['however',
#    'decided',
#    'rejoin',
#    'crhk',
#    'host',
#    'brand',
#    'new',
#    'programme',
#    'station',
#    'october',
#    '204',
#    'allen',
#    'lee',
#    'peng',
#    'fei',
#    'replaced',
#    'cheng',
#    'jing',
#    'han',
#    'announced',
#    'resignation',
#    '19',
#    'may',
#    'also',
#    'political',
#    'reasons']],
#  [['henry',
#    'epistola',
#    'concili',
#    'pacis',
#    'printed',
#    'von',
#    'der',
#    'hardt',
#    'concilium',
#    'constantiense',
#    'ii',
#    '1',
#    '360',
#    'exception',
#    'first',
#    'second',
#    'chapter',
#    'afterwards',
#    'published',
#    'author',
#    'discrepantia',
#    'mss'],
#   ['et',
#    'editionum',
#    'helmstadt',
#    '1715',
#    '91',
#    '1382',
#    'french',
#    'court',
#    'compelled',
#    'professors',
#    'sorbonne',
#    'acknowledge',
#    'antipope',
#    'clement',
#    'vii',
#    'henry',
#    'left',
#    'university',
#    'spent',
#    'time',
#    'eberbach',
#    'abbey',
#    'cistercian',
#    'monastery',
#    'near',
#    'wiesbaden'],
#   ['letter',
#    'wrote',
#    'bishop',
#    'eckard',
#    'worms',
#    'bears',
#    'title',
#    'de',
#    'scismate',
#    'edited',
#    'somerfeldt',
#    'historisches',
#    'jahrbuch',
#    'munich',
#    '1909',
#    'xxx',
#    '461']],
#  [['triple',
#    'h',
#    'confronted',
#    'rolins',
#    'ordered',
#    'security',
#    'eject',
#    'rolins',
#    'arena'],
#   ['rolins', 'attacked', 'security', 'guards', 'eventually', 'taken', 'away'],
#   ['main',
#    'event',
#    'shinsuke',
#    'nakamura',
#    'defended',
#    'nxt',
#    'championship',
#    'bobby',
#    'rode'],
#   ['rode', 'targeted', 'nakamura', 'leg', 'throughout', 'match', 'injured']],
#  [['san', 'antonio'],
#   ['announced',
#    'via',
#    'we',
#    'official',
#    'website',
#    'january',
#    '25',
#    '2017',
#    'preshow',
#    'panel',
#    'would',
#    'consist',
#    'charly',
#    'caruso',
#    'raw',
#    'announcer',
#    'corey',
#    'graves',
#    'recent',
#    'united',
#    'kingdom',
#    'championship',
#    'tournament',
#    'commentator',
#    'nigel',
#    'mcguines'],
#   ['graves',
#    'announced',
#    'preshow',
#    'would',
#    'last',
#    'takeover',
#    'show',
#    'nxt',
#    'color',
#    'commentator',
#    'officially',
#    'set',
#    'role',
#    'raw',
#    'color',
#    'commentator']],
#  [['however',
#    'stevenson',
#    'suffered',
#    'injury',
#    'training',
#    'replaced',
#    'tyson',
#    'griffin'],
#   ['gomi', 'defeated', 'griffin', 'ko', 'punch', '104', 'first', 'round'],
#   ['gomi',
#    'would',
#    'finish',
#    'left',
#    'cross',
#    'following',
#    'right',
#    'hook',
#    'causing',
#    'griffin',
#    'fall',
#    'face',
#    'first',
#    'canvas',
#    'gomi',
#    'followed',
#    'onto',
#    'griffin',
#    'back',
#    'short',
#    'punches',
#    'fight',
#    'stopped'],
#   ['first',
#    'person',
#    'stopped',
#    'griffin',
#    'griffin',
#    'previous',
#    'losses',
#    'gone',
#    'decision']],
#  [['sheep',
#    'milk',
#    'gnudi',
#    'scored',
#    'carie',
#    'chicken',
#    'fried',
#    'ribeye',
#    'put',
#    'sugar',
#    'mashed',
#    'potato',
#    'used',
#    'amanda',
#    'eggplant',
#    'rolatini',
#    'brendan',
#    'salmon',
#    'scored',
#    'point',
#    'jenifer',
#    'pork',
#    'scored',
#    'jonathon',
#    'punchdrunk',
#    'chicken',
#    'even',
#    'threatened',
#    'elimination',
#    'spot',
#    'revealed',
#    'ramsay',
#    'used',
#    'canned',
#    'pineapple',
#    'slices',
#    'dish',
#    'claimed',
#    'limited',
#    'time',
#    'paul',
#    'eggplant',
#    'involtini',
#    'scored',
#    'krupa',
#    'stuffed',
#    'naan',
#    'neither',
#    'jamie',
#    'lamb',
#    'lollipops',
#    'steven',
#    'seared',
#    'diver',
#    'scallops',
#    'earned',
#    'point',
#    'ramsay',
#    'even',
#    'compared',
#    'steven',
#    'scallops',
#    'dinosaur',
#    'toenails',
#    'elise',
#    'scallops',
#    'scored',
#    'chino',
#    'dish',
#    'used',
#    'much',
#    'miso',
#    'monteray',
#    'sea',
#    'bass',
#    'natalie',
#    'lamb',
#    'scored',
#    'point',
#    'elizabeth',
#    'tomy',
#    'earned',
#    'point',
#    'dishes',
#    'finally',
#    'gina',
#    'panroasted',
#    'pistachio',
#    'scallops',
#    'lost',
#    'jason',
#    'pork',
#    'tacos',
#    'scallops',
#    'burnt',
#    'top']],
#  [['women',
#    'cleaned',
#    'grills',
#    'drank',
#    'blended',
#    'meat',
#    'preped',
#    'side',
#    'beef'],
#   ['service',
#    'carie',
#    'served',
#    'tableside',
#    'caesar',
#    'salad',
#    'krupa',
#    'monteray',
#    'served',
#    'tableside',
#    'prime',
#    'ribs'],
#   ['red',
#    'kitchen',
#    'jenifer',
#    'served',
#    'squab',
#    'brisket',
#    'carie',
#    'slow',
#    'serving',
#    'caesar',
#    'salads',
#    'causing',
#    'ramsay',
#    'send',
#    'krupa',
#    'help',
#    'krupa',
#    'later',
#    'dropped',
#    'prime',
#    'rib',
#    'floor']],
#  [['meet',
#    'travis',
#    'nic',
#    'testoni',
#    'joel',
#    'nash',
#    'david',
#    'wodley',
#    'boats',
#    'nearly',
#    'collide',
#    'due',
#    'mara',
#    'careless',
#    'driving'],
#   ['mara', 'pursues', 'interest', 'joel', 'unaware', 'married'],
#   ['denise',
#    'former',
#    'celmate',
#    'kylie',
#    'burton',
#    'rosyln',
#    'oades',
#    'uses',
#    'alias',
#    'magie',
#    'crowley',
#    'visits',
#    'kylie',
#    'exfianc',
#    'jese',
#    'mcgregor',
#    'ben',
#    'unwin'],
#   ['jese',
#    'grows',
#    'close',
#    'discovers',
#    'denise',
#    'escapee',
#    'used',
#    'guard',
#    'identity']],
#  [['batman',
#    'forced',
#    'fight',
#    'beloved',
#    'sidekick',
#    'cures',
#    'back',
#    'batcave',
#    'following',
#    'two',
#    'face',
#    'casino',
#    'fact',
#    'revealed',
#    'dent',
#    'suppressed',
#    'bad',
#    'side',
#    'la',
#    'dr',
#    'jekyl',
#    'mr',
#    'hyde'],
#   ['dynamic',
#    'duo',
#    'strapped',
#    'large',
#    'silver',
#    'dollar',
#    'unmasks',
#    'batman',
#    'deduces',
#    'robin',
#    'true',
#    'identity',
#    'two',
#    'face',
#    'invites',
#    'joker',
#    'penguin',
#    'ridler',
#    'mr',
#    'freeze',
#    'egghead',
#    'shame',
#    'clock',
#    'king',
#    'catwoman',
#    'auction',
#    'highest',
#    'bidder',
#    'batman',
#    'true',
#    'identity']],
#  [['fly',
#    'confront',
#    'king',
#    'tut',
#    'one',
#    'final',
#    'battle',
#    'brick',
#    'restores',
#    'memory'],
#   ['take', 'away', 'pair', 'twins', 'seize', 'jewels', 'stolen', 'tutlings'],
#   ['batman',
#    'robin',
#    'commissioner',
#    'gordon',
#    'chief',
#    'ohara',
#    'interrogate',
#    'king',
#    'tut',
#    'harvey',
#    'waits',
#    'shadows',
#    'ohara',
#    'constantly',
#    'hitting',
#    'tut',
#    'head',
#    'baton']],
#  [['film',
#    'made',
#    'backdrop',
#    'communal',
#    'tension',
#    'formation',
#    'muslim',
#    'league'],
#   ['shantaram',
#    'attempted',
#    'theme',
#    'showing',
#    'amicable',
#    'relations',
#    'hindus',
#    'muslims'],
#   ['achieve',
#    'better',
#    'geniality',
#    'mazhar',
#    'khan',
#    'muslim',
#    'playing',
#    'role',
#    'hindu',
#    'gajanan',
#    'jagirdar',
#    'hindu',
#    'play',
#    'muslim',
#    'character'],
#   ['trio',
#    'social',
#    'films',
#    'especially',
#    'padosi',
#    'shantaram',
#    'cited',
#    'author',
#    'bajaj',
#    'third',
#    'best',
#    'director',
#    'pre1960',
#    'top',
#    'ten',
#    'rating',
#    'following',
#    'p',
#    'c',
#    'barua',
#    'devdas',
#    '1935',
#    'homi',
#    'wadia',
#    'miss',
#    'frontier',
#    'mail',
#    '1936',
#    'followed',
#    'mehbob',
#    'khan',
#    'mother',
#    'india',
#    '1957']],
#  [['fourthplace',
#    'finish',
#    'seasonal',
#    'debut',
#    'owner',
#    'dizney',
#    'decided',
#    'give',
#    'first',
#    'dude',
#    'change',
#    'scenery',
#    'moved',
#    'southern',
#    'californiabased',
#    'trainer',
#    'bob',
#    'bafert'],
#   ['first',
#    'dude',
#    'made',
#    'first',
#    'start',
#    'bafert',
#    'santa',
#    'anita',
#    'handicap',
#    'finished',
#    'sixth',
#    'behind',
#    'stablemate',
#    'game',
#    'dude',
#    'battling',
#    'lead'],
#   ['bafert',
#    'decided',
#    'school',
#    'first',
#    'dude',
#    'told',
#    'jockey',
#    'martin',
#    'garcia',
#    'keep',
#    'first',
#    'dude',
#    'pace',
#    'let',
#    'make',
#    'moves']],
#  [['lord',
#    'lady',
#    'brokeborough',
#    'three',
#    'sons',
#    'two',
#    'killed',
#    'action',
#    'world',
#    'war',
#    'ii'],
#   ['one', 'son', 'survived', 'parents'],
#   ['senior',
#    'commandant',
#    'auxiliary',
#    'territorial',
#    'service',
#    'second',
#    'world',
#    'war'],
#   ['cynthia',
#    'brooke',
#    'styled',
#    'viscountess',
#    'brokeborough',
#    '1',
#    'july',
#    '1952',
#    'husband',
#    'created',
#    'viscount',
#    'brokeborough']],
#  [['brewers',
#    'went',
#    'series',
#    'scuffles',
#    'early',
#    'september',
#    'division',
#    'lead',
#    'high',
#    '10',
#    'games',
#    'late',
#    'august',
#    'went',
#    '45',
#    'games',
#    'cardinals',
#    'went',
#    'sudden',
#    'hot',
#    'streak',
#    'becoming',
#    'first',
#    'team',
#    'sweep',
#    'brewers',
#    'miller',
#    'park',
#    'season'],
#   ['brewers',
#    'though',
#    'able',
#    'keep',
#    'division',
#    'lead',
#    'steady',
#    'thanks',
#    'midseptember',
#    'sweep',
#    'reds'],
#   ['september', '16', 'ryan', 'braun', 'hit', '30th', 'home', 'run', 'season'],
#   ['along',
#    '31',
#    'stolen',
#    'bases',
#    'braun',
#    'became',
#    '2nd',
#    'brewer',
#    'ever',
#    '30homer',
#    '30steal',
#    'season',
#    'joining',
#    'tomy',
#    'harper',
#    'accomplished',
#    'feat',
#    '1970']],
#  [['ireatha',
#    'watson',
#    '89',
#    'rose',
#    'savoie',
#    '90',
#    'administering',
#    'causing',
#    'administered',
#    'lethal',
#    'doses',
#    'morphine',
#    'sulphate',
#    'morphine',
#    'andor',
#    'midazolam',
#    'versed'],
#   ['according',
#    'kristy',
#    'johnson',
#    'lifecare',
#    'director',
#    'physical',
#    'medicine',
#    'pou',
#    'told',
#    'patients',
#    'administering',
#    'drugs',
#    'make',
#    'feel',
#    'better']],
#  [['agreed', 'henry', 'paid', 'hefty', 'sum', 'money'],
#   ['next', 'day', 'jane', 'disappeared', 'henry', 'realized', 'conned'],
#   ['linked', 'kieran', 'threatened'],
#   ['kieran',
#    'realised',
#    'henry',
#    'making',
#    'money',
#    'selling',
#    'shares',
#    'horse',
#    'multiple',
#    'people',
#    'keeping',
#    'race',
#    'money']],
#  [['final',
#    'nail',
#    'coffin',
#    'thought',
#    'issue',
#    'finances',
#    'ekta',
#    'smriti',
#    'latter',
#    'demanded',
#    'raise',
#    'former',
#    'rejected'],
#   ['last',
#    'episode',
#    'feature',
#    'smriti',
#    'telecasted',
#    '6',
#    'june',
#    '207',
#    'dies',
#    'truck',
#    'accident'],
#   ['long',
#    'hiatus',
#    '11',
#    'months',
#    'amidst',
#    'decline',
#    'kyunki',
#    'viewership',
#    'ekta',
#    'kapor',
#    'got',
#    'back',
#    'smriti',
#    'role',
#    'highly',
#    'publicized',
#    'affair',
#    'buried',
#    'hatchet',
#    'public',
#    'appearance']],
#  [['though',
#    'writing',
#    'libretto',
#    'progressed',
#    'certain',
#    'versions',
#    'showed',
#    'grimes',
#    'relations',
#    'apprentice',
#    'paederastic',
#    'pears',
#    'persuaded',
#    'slater',
#    'cut',
#    'questionable',
#    'stanzas',
#    'final',
#    'version'],
#   ['many',
#    'scholars',
#    'instead',
#    'viewing',
#    'celebration',
#    'grimes',
#    'abuse',
#    'look',
#    'britten',
#    'condemnation',
#    'homophobia',
#    'era',
#    'understood',
#    'destructive',
#    'sociological',
#    'consequences']],
#  [['also', '198', 'yearend', 'wta', 'tour', 'championships'],
#   ['sabatini',
#    'next',
#    'grand',
#    'slam',
#    'singles',
#    'final',
#    'came',
#    '190',
#    'faced',
#    'graf',
#    'final',
#    'us',
#    'open'],
#   ['time',
#    'sabatini',
#    'beat',
#    'graf',
#    '6',
#    '2',
#    '7',
#    '6',
#    'also',
#    'beat',
#    'graf',
#    'semifinal',
#    'wta',
#    'tour',
#    'championships',
#    'lost',
#    'final',
#    'monica',
#    'seles',
#    'event',
#    'firstever',
#    'fiveset',
#    'final',
#    '6',
#    '4',
#    '5',
#    '7',
#    '3',
#    '6',
#    '6',
#    '4',
#    '6',
#    '2']],
#  [['lucky',
#    'daughter',
#    'rebellious',
#    'teenager',
#    'maria',
#    'also',
#    'known',
#    'max',
#    'arranging',
#    'meet',
#    'mysterious',
#    'boy',
#    'internet',
#    'hopes',
#    'making',
#    'exboyfriend',
#    'jealous'],
#   ['however',
#    'mystery',
#    'boy',
#    'turns',
#    'midleaged',
#    'man',
#    'named',
#    'henry',
#    'hatred',
#    'max',
#    'mother',
#    'lucky',
#    'cast',
#    'movie',
#    'developed',
#    'years',
#    'ago']],
#  [['christa',
#    'brittany',
#    'allen',
#    'born',
#    'november',
#    '11',
#    '191',
#    'american',
#    'actress',
#    'best',
#    'known',
#    'role',
#    'younger',
#    'jena',
#    'rink',
#    '204',
#    'movie',
#    '13',
#    'going',
#    '30',
#    'allen',
#    'born',
#    'wildomar',
#    'california'],
#   ['youngest',
#    'five',
#    'siblings',
#    'four',
#    'elder',
#    'brothers',
#    'well',
#    'four',
#    'elder',
#    'stepbrothers'],
#   ['role',
#    'jena',
#    '13',
#    'going',
#    '30',
#    'allen',
#    'done',
#    'short',
#    'appearance',
#    'man',
#    'show',
#    'several',
#    'students',
#    'films',
#    'several',
#    'commercials'],
#   ['starred',
#    'titular',
#    'character',
#    'cbs',
#    'saturday',
#    'morning',
#    'tv',
#    'series',
#    'cake']],
#  [['francis',
#    'france',
#    'restored',
#    'usual',
#    'name',
#    'early',
#    '16th',
#    'century',
#    'took',
#    'nickname',
#    'le',
#    'bistourn',
#    'twiceturned',
#    'church',
#    'later',
#    'bowdlerised',
#    'le',
#    'bestourn',
#    'possibly',
#    'bring',
#    'back',
#    'closer',
#    'old',
#    'name'],
#   ['one',
#    'church',
#    'chaplains',
#    'guilaume',
#    'de',
#    'villon',
#    'tutor',
#    'franois',
#    'villon',
#    'charles',
#    'perault',
#    'buried',
#    'church'],
#   ['middle',
#    'ages',
#    'church',
#    'housed',
#    'altar',
#    'maturinus',
#    'patron',
#    'mad',
#    'possessed',
#    'around',
#    'devotion',
#    'sprang',
#    'many',
#    'ill',
#    'people',
#    'brought',
#    'hope',
#    'cure']],
#  [['james',
#    'jimmy',
#    'kidega',
#    'born',
#    '16',
#    'august',
#    '1982',
#    'ugandan',
#    'former',
#    'footballer',
#    'played',
#    'midfielder'],
#   ['born',
#    'jinja',
#    'brother',
#    'moses',
#    'oloya',
#    'also',
#    'played',
#    'international',
#    'football',
#    'uganda'],
#   ['kidega',
#    'played',
#    'club',
#    'football',
#    'sc',
#    'villa',
#    'express',
#    'rayon',
#    'sports',
#    'la',
#    'passe',
#    'gulu',
#    'united',
#    'uganda',
#    'revenue',
#    'authority',
#    'chanthaburi',
#    'bontang'],
#   ['also', 'earned', 'two', 'caps', 'ugandan', 'national', 'team']],
#  ...]
